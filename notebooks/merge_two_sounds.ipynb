# %%
import pyrootutils.root
import IPython
from src import *

# %%
signal_1, sr = load_audio_wav('data/audio_wav/IDMT_Traffic/2020-08-29-14-02_Hohenwarte_unknownKmh_4660624_M_D_ML_SE_CH12.wav', True)
signal_2, sr = load_audio_wav('data/audio_wav/IDMT_Traffic/2020-08-29-14-02_Hohenwarte_unknownKmh_4699956_M_D_MR_SE_CH12.wav', True)
# signal_2 = load_audio('2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_1137602_M_D_CL_SE_CH34')

# %%
signal_1 = T.Resample(sr, 41000).forward(signal_1)
signal_2 = T.Resample(sr, 41000).forward(signal_2)

# %%
signal_1.shape, signal_2.shape
# Out:
# (torch.Size([82000]), torch.Size([82000]))

# %%
IPython.display.Audio(signal_1.numpy(), rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(signal_2.numpy(), rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal_3 = signal_1 + signal_2

# %%
IPython.display.Audio(signal_3.numpy(), rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
